# %% [markdown]
# *  Create classes Esewa, Khalti, and
# BankTransfer, each having a pay(amount)
# method. Write a payment processor function
# that works with any payment method object. (Duck Typing)

# %%
class Esewa:
    def pay(self, amount):
        print(f"Esewa payment of {amount} successful.")

class Khalti:
    def pay(self, amount):
        print(f"Khalti payment of {amount} successful.")

class BankTransfer:
    def pay(self, amount):
        print(f"Bank transfer payment of {amount} successful.")

def payment_processor(payment_method, amount):
    payment_method.pay(amount)

esewa = Esewa()
khalti = Khalti()
bank_transfer = BankTransfer()

payment_processor(esewa, 100)
payment_processor(khalti, 50)
payment_processor(bank_transfer, 200)
# Out:
# Esewa payment of 100 successful.
# Khalti payment of 50 successful.
# Bank transfer payment of 200 successful.

# %% [markdown]
# #**Magic Methods**
# **Magic methods** (also called dunder methods, short for
# "double underscore") are special methods with names
# surrounded by double underscores, such as **_ _init _ _** ,
# **_ _ str _ _** ,  and **_ _ len _ _**.
#
#  Here are some of the most commonly used magic methods in Python:
# * **_ _ init _ _**: Initializes an object of a class when it is created
# * **_ _ str _ _**: Defines how an object is printed as a string
# * **_ _ repr _ _**: Defines the string representation of an object, which can be used to recreate the object
# * **_ _ len _ _**: Defines length of an object
# * **_ _ call _ _**: Calls objects of the class like a normal function

# %%
dir(Esewa)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'pay']

# %%
class BankCustomer:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  # Called by print()
  def __str__(self):
    return f"{self.name} is {self.age} years old"

  # Called by repr()
  def __repr__(self):
    return f"BankCustomer('{self.name}', {self.age})"

  # Called by len() and be used by integer not string
  def __len__(self):
    return self.age

  # Makes object callable like a function
  def __call__(self, gender="Male"):
    return f"{self.name} is a {gender}"

# Create object
customer = BankCustomer("Bibek", 22)

# __str__
print(customer)

# __repr__
print(repr(customer))

# __len__
print(len(customer))

# __call__
print(customer())

print(customer("Female"))
# Out:
# Bibek is 22 years old
# BankCustomer('Bibek', 22)
# 22
# Bibek is a Male
# Bibek is a Female

# %% [markdown]
# * Create a BankAccount class and implement __ str__()
# and __ repr__() methods to display account details in
# user-friendly and developer-friendly formats.
#
# **Note:** here __ str __() is user-friendly and __ repr __ () is developer-friendly

# %%
class BankAccount:
  def __init__(self, name, account_number, balance):
    self.account_number = account_number
    self.balance = balance
    self.name = name

  def __str__(self):
    return f"Account No: {self.account_number} \nName: {self.name} \nBalance: {self.balance}"

  def __repr__(self):
    return f"BankAccount('{self.name}', {self.account_number}, {self.balance})"


name = input("Enter the name: ")
account_number = input("Enter the account Number: ")
balance = input ("Enter the balance: ")

bankaccount = BankAccount(name, account_number, balance)

print("\n\n")

print(bankaccount)

print("\n\n")

print(repr(bankaccount))
# Out:
# Enter the name: Ronaldo
# Enter the account Number: 21654154131
# Enter the balance: 1000
#
#
#
# Account No: 21654154131
# Name: Ronaldo
# Balance: 1000
#
#
#
# BankAccount('Ronaldo', 21654154131, 1000)

# %% [markdown]
# # __str__ and __repr__ methods seem similar. How do they serve different purposes?
#
# **str(obj)** method is used to return a string representation of an object that is meant to be human-readable. It is generally used for printing the object,
# logging, and displaying information to the user.
#
# **repr(obj)** method, on the other hand, is used to return a string representation of an object that is meant to be unambiguous and suitable for debugging. It should ideally return a string that can be used to recreate the object.
#
#
# Meaning even if both returns the string, we format is such that one can be understood by anyone and another can be understood by a developer who has knowledge of internal code.
#
# one i showed like Name: Ronaldo, Balance: 1000 so it is human readable but another one is like BankAccount ('Ronaldo',1000) which could understood only when we know about the object so it is a representation of an object

# %% [markdown]
# # **File Handling**
# File handling refers to the process of performing operations on a file, such as
# creating, opening, reading, writing and closing it through a programming interface. It involves managing the data flow between the program and the file system on the storage device, ensuring that data is handled safely and efficiently.
#
# File handling is an import part of programming which allows us to create,
# read, update and delete files. In Python to handle data we use open() built-in
# function.
#
#
# # Syntax
#
# ```
# open('filename', mode) # mode(r, a, w, x, t,b) could be to read, write, update
# ```
#
#
# * "r" - Read - Default value. Opens a file for reading, it returns an error if the file does not exist
# * "a" - Append - Opens a file for appending, creates the file if it does not exist
# * "w" - Write - Opens a file for writing, creates the file if it does not exist
# * "x" - Create - Creates the specified file, returns an error if the file exists
# * "t" - Text - Default value. Text mode
# * "b" - Binary - Binary mode (e.g. images)

# %% [markdown]
# #Opening Files for Reading
# The default mode of open is reading, so we do not have to specify 'r' or 'rt'. I
# have created and saved a file named reading_file_example.txt in the files
# directory. Let us see how it is done:

# %%
f = open('reading_file_example.txt')
print(f)
# Out:
# <_io.TextIOWrapper name='reading_file_example.txt' mode='r' encoding='utf-8'>

# %%
txt = f.read()
print(txt)
print("\n\n")
print(type (txt))
# Out:
# Hello Guys, Are you fine ?
# I am also good, what are you doing?
# I am exploring too!!
#
#
#
# <class 'str'>

# %%
line = f.readline()
print(line)
line = f.readline()
print("\n")
print(line)
line = f.readline()
print("\n")
print(line)
print("\n")
print(type (line))
# Out:
# Hello Guys, Are you fine ?
#
#
#
# I am also good, what are you doing?
#
#
#
# I am exploring too!!
#
#
# <class 'str'>

# %%
lines = f.readlines()
print(lines)
print("\n")
print(type (lines))
# Out:
# ['Hello Guys, Are you fine ?\n', 'I am also good, what are you doing?\n', 'I am exploring too!!']
#
#
# <class 'list'>

# %%
lines = f.read().splitlines()
print(lines)
print("\n")
print(type (lines))
# Out:
# ['Hello Guys, Are you fine ?', 'I am also good, what are you doing?', 'I am exploring too!!']
#
#
# <class 'list'>

# %%
f.close
# Out:
# <function TextIOWrapper.close()>

# %% [markdown]
# # **Opening Files for Writing and Updating**
# To write to an existing file, we must add a mode as parameter to the open() function:
#
# * "a" - append - will append to the end of the file, if the file does not exist it creates a new file.
# * "w" - write - will overwrite any existing content, if the file does not exist, it creates the file.
#
# Let us append some text to the file we have been reading:
#
# ```
# with open('./files/reading_file_example.txt', 'a') as f:
# f.write('This text has to be appended at the end')
# ```
#
# The method below creates a new file, if the file does not exist:
#
# ```
# with open('./files/writing_file_example.txt', 'w') as f:
# f.write('This text will be written in a newly created file')
# ```

# %%
f = open('writing_file_example.txt', 'w')
f.write('This text will be written in a newly created file')
f.close()

# %%
f = open('writing_file_example.txt','a')
f.write('\n This text has to be appended at the end')
f.write('\n This text has to be appended at the end')
f.close()

# %% [markdown]
# #To Delete a File
# First we import os then write os.remove with the file path to delete the file

# %%
import os
os.remove('writing_file_example.txt')

# %%
import os
if os.path.exists('writing_file_example.txt'): #this will check if the file exist in the required path
  os.remove('writing_file_example.txt')
  print("File is successfully removed")
else:
  print('The file does not exist')
# Out:
# The file does not exist

# %% [markdown]
# # Dumping / Adding in json file
#
# An indent in JSON dumping is an option used to format the output with spaces and line breaks so it is easy for humans to read

# %%
import json

person ={
"name": "dhiraj",
"country": "Nepal",
"skills" : "ML Developer"
}

person_dct = json.dumps(person, indent= 4)
print(type(person_dct))


f = open('person.json', 'w')
f.write(person_dct)
f.close()
# Out:
# <class 'str'>

# %% [markdown]
# # Loading / Reading from json file

# %%
import json


f = open('person.json', 'r')
person_dct = json.load(f)
f.close()


print(type(person_dct))

print("\n\n")
print(person_dct)
# Out:
# <class 'dict'>
#
#
#
# {'name': 'dhiraj', 'country': 'Nepal', 'skills': 'ML Developer'}
