# %%
#Doc
print(dir.__doc__)
#help()

print("\n \n \n")
print(help(print))
# Out:
# dir([object]) -> list of strings
#
# If called without an argument, return the names in the current scope.
# Else, return an alphabetized list of names comprising (some of) the attributes
# of the given object, and of attributes reachable from it.
# If the object supplies a method named __dir__, it will be used; otherwise
# the default dir() logic is used and returns:
#   for a module object: the module's attributes.
#   for a class object:  its attributes, and recursively the attributes
#     of its bases.
#   for any other object: its attributes, its class's attributes, and
#     recursively the attributes of its class's base classes.
#
#
#
#
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
# ...

# %%
#what does doc does is read the txt in docstring
#it is written in ''' message '''
#accessable in run time
#used in module, functions and classes

def sum (a,b):
  ''' It prints sum of arguments'''
  return a+b
print (sum.__doc__)
# Out:
#  It prints sum of arguments

# %%
#This is *args and **kwargs where args is name and can be anything
#look in print n it takes only 1 value so 3 came and since 3 is already taken
#args took tuple as argument and kwargs took dictionary as argument
def data3( n, *args, ** kwargs):#here n should be always in first
  print(n)
  print(args)
  print(kwargs)

data3(3,2,3,4,5 ,s=1,s1=4)
# Out:
# 3
# (2, 3, 4, 5)
# {'s': 1, 's1': 4}

# %%
def pizza (n,*ingridients,**customer_details):
  print("The number of pizza is: ",n)
  print("Ingridients: \n")
  for i in ingridients:
    print("-",i)
  print("\nCustomer Details: \n")
  for i in customer_details.items():
    print(i)
#pizza(1,"Olive oil","tomato","Chicken","Yak Cheese",name = 'Pizzalover', address = 'USA')
num = int (input("Enter the number of pizza: \n"))
while
pizza(num,lst,dic)
# Out:
# The number of pizza is:  1
# Ingridients:
#
# - Olive oil
# - tomato
# - Chicken
# - Yak Cheese
#
# Customer Details:
#
# ('name', 'Pizzalover')
# ('address', 'USA')
