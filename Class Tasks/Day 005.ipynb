# %% [markdown]
# #**if condition syntax**
# ```
# if ___ condition ___:
# the thing if its true
# elif ___ condtion ___:
# if its true
# else:
# if condition is not true
# ```

# %%
age = int(input("enter your age \n"))
if age < 18 :
  print ("age is less than 18")
elif age == 18:
  print ("age is 18")
elif age > 18 and age < 40 :
  print ("age is greater than 18 and less than 40")
elif age == 40:
  print ("age is 40")
else:
  print ("age is greater than 40")
# Out:
# enter your age
# 21
# age is greater than 18 and less than 40

# %%
age = int(input("enter your age \n"))
citizenship = input("enter country of your citizenship \n")
if age >= 18 and citizenship.upper().strip() == "NEPAL":
  print ("You can vote")
else:
  print ("You can not vote")
# Out:
# enter your age
# 21
# enter country of your citizenship
# india
# You can not vote

# %%
marks = float(input("enter your marks \n"))
if marks > 4.0:
  marks = marks/25
if  marks > 3.60 and marks <= 4.0:
  print ("Grade: A+ \nRemarks: Outstanding")
elif marks > 3.20 and marks <= 3.60:
  print ("Grade: A \nRemarks: Excellent")
elif marks > 2.80 and marks <= 3.20:
  print ("Grade: B+ \nRemarks: Very Good")
elif marks > 2.4 and marks <= 2.80:
  print ("Grade: B \nRemarks: Satisfactory")
elif marks > 2.0 and marks <= 2.40:
  print ("Grade: C+ \nRemarks: Acceptable")
elif marks > 1.6 and marks <= 2.0:
  print ("Grade: C \nRemarks: Basic")
else:
  print ("Grade: NG \nRemarks: Not Graded")
# Out:
# enter your marks
# 89
# Grade: A
# Remarks: Excellent

# %%
age = int(input("enter your age \n"))
membership = input("enter your membership status \n")
if age >= 40 and membership.lower().strip() == "yes":
  print ("You can apply for 60% discount")
elif age >= 40 and membership.lower().strip() == "no":
  print ("You can apply for 40% discount")
elif age < 40 and membership.lower().strip() == "yes":
  print ("You can apply for 20% discount")
else:
  print ("Sorry there is no discount available")
# Out:
# enter your age
# 18
# enter your membership status
# no
# Sorry there is no discount available

# %%
lst = [3,2,7,9]
no= int(input("enter a number \n"))
if no % 2 == 0 :
  lst.append(no)
  print(lst)
else:
  lst.pop()
  print (lst)
# Out:
# enter a number
# 2
# [3, 2, 7, 9, 2]
