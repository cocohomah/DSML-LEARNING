# %%
number = 1
print(type(number))
# Out:
# <class 'int'>

# %%
number = 1.3
type (number)
# Out:
# float

# %%
number = 3+3j
type (number)
# Out:
# complex

# %%
a = 3.4
a = int (a)
a
# Out:
# 3

# %%
a= 57
b=2
print(a//b)
print(a**b)
print(a%b)
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 28
# 3249
# 1
# 59
# 55
# 114
# 28.5

# %%
a = 2
b = 5
if a > b : print ( a ,"is greater than", b )
elif b > a : print ( b, "is greater than" , a)
else : print ("they are equal")
# Out:
# 5 is greater than 2

# %%
import math
a = 5
print ("the factorial of 5 (5!)=", math.factorial(5))
print ("the rounding number of 4.5 is", math.ceil(4.5))
print ("the integer value of number 4.5 is ", math.floor(4.5))
print ("the square root of 40 is", math.sqrt(49))
print ("the HCF of 4, 6, 2 =", math.gcd (4,6,2))
print ("the first 2 digit after decimal of 22.542 is", round (22.542,2))
print ("smallest number among 640 and 128 is ", min(640,128))
# Out:
# the factorial of 5 (5!)= 120
# the rounding number of 4.5 is 5
# the integer value of number 4.5 is  4
# the square root of 40 is 7.0
# the HCF of 4, 6, 2 = 2
# the first 2 digit after decimal of 22.542 is 22.54
# smallest number among 640 and 128 is  128

# %%
a = "Its a 'sunny' day"
b ='He said "hello" '
c = "hello "
d = 'world'
e = "hello python"
print (a)
print (b)
print (c, "\n",d,  "\n Are they equal? \n Answer:", c == d, "\n",c+d, "\n" , c*3 )
print ( d[1:4:2] ) # slicing ho where syntax is variable [start : end : step ]
print (d[3] )
print( d[-2])
print ( d[:3] )
print ( d[::2] )
print (e[1:-1])
print (e[:-1 : 2])
print ("'len' gives length of string including space for example \n",len (e), "\n", len (d))
# Out:
# Its a 'sunny' day
# He said "hello"
# hello
#  world
#  Are they equal?
#  Answer: False
#  hello world
#  hello hello hello
# ol
# l
# l
# wor
# wrd
# ello pytho
# hlopto
# 'len' gives length of string including space for example
#  12
#  5

# %%
a = " hello man #"
print (a.replace("man","human"))
print (a.upper())
print (a.lower())
print (a.title())
print (a.strip("#"))
print (a.strip())
print (a.split())
print (a.split(maxsplit=1))
# Out:
#  hello human #
#  HELLO MAN #
#  hello man #
#  Hello Man #
#  hello man
# hello man #
# ['hello', 'man', '#']
# ['hello', 'man #']

# %%
a = "helloworld.txt"
 #a.endswith("txt") gives boolean value for example
b = a.endswith("txt")
print (b)

if a.endswith("txt") :
  print ("its a text file")
else :
 print ("its not a text file")
# Out:
# True
# its a text file
